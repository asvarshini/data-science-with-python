# %%
#variable,A variable is a name that stores a value in memory.
'''
Can contain letters, numbers, underscore
✔ Cannot start with number
✔ Case sensitive
✔ Cannot use keywords'''
name ="varsh"
age =28
print (name,age)
# Out:
# varsh 28

# %%
# Dynamic Typing (Python Special Feature)
#because varialble type fixed at runtime
x =10
y="string"

# %%
#DATA TYPES (VERY VERY IMPORTANT )
#int all numbers
x =10
#flot decimal number
x =1.0
#string words
x ="Python"
#complex
x =2+3j
#boolen
bool(0)
bool(1)
#What values are considered False?
#0 None "" [] {} Fals2 Everything else → True
# Out:
# True

# %%
i =33
f=2.3
b=True

print(type(i))
print(type(f))
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
#string methods
''' lower()
upper()
strip()
replace()
split()
join()
find()
count()'''
string ="Python"
string[0:4]  #[start : stop : step]
#Think like range() → last number not included.
string.upper()
print(string)
string.lower()
string.replace("P" ,"y")
# Out:
# Python
# 'yython'

# %%
#split
string.split('t')
# Out:
# ['Py', 'hon']

# %%
#Join "separator".join(iterable)
s1="Data"
s2 ="Science"
s1.join(s2)
#1
"".join([s1, s2])
#or
s1+s2
# Out:
# 'DataScience'

# %%
#real use of join
words =["Data","Science"]
"-".join(words)
# Out:
# 'Data-Science'

# %%
#What happens if elements are not strings?
#convert it into string
number =[2,6,7]
"".join(map(str,number))
# Out:
# '267'

# %%
"-".join("ABC")#join iterable
# Out:
# 'A-B-C'

# %%
#find  string.find(substring)
#returns index if found or -1 if not found
string="poop"
string.find("A")
# Out:
# -1

# %%
string.find('o',2)
# Out:
# 2

# %%
s ="hello world"
s.find("world")
# Out:
# 6

# %%
#index not found throw error
words.index("Science")
# Out:
# 1

# %%
words.index("poop")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1145684791.py in <cell line: 0>()
# ----> 1 words.index("poop")
#
# ValueError: 'poop' is not in list

# %%
#count  It counts substring, not words
x ="I am learning Python"
x.count("am")
# Out:
# 1

# %%
x.count("m") #m present only once
# Out:
# 1

# %%
x.count("a") #it does not overlap it give index of last is 2 words repeats
# Out:
# 2

# %%
x.count("y")
# Out:
# 1

# %%
#Non overlaping
x = "amamam"
x.count("am")
# Out:
# 3

# %%
Fruite="apple NAME"
#1 upper,lower,title
print(Fruite.upper())
print(Fruite.lower())
print(Fruite.title())
print(Fruite.upper())
print(Fruite.capitalize())
# Out:
# APPLE NAME
# apple name
# Apple Name
# APPLE NAME
# Apple name

# %%
#type cating int ->float->boolean
int("10")+5
# Out:
# 15

# %%
#implicete converstion python convert small type into large automatically
print(5.0+2)
# Out:
# 7.0

# %%
#Explicit Typecasting (Manual)
#int
int(5.9)       # 5
int("10")      # 10
int("10.5")#error  #Because string must be whole number.
int(float("10.5")) #correct way

# %%
#str convert everything into string
str(10)      # "10"
str(5.5)     # "5.5"

# %%
#bool converts evrthing into flase
bool(0)      # False
bool(100)    # True
bool("")     # False
bool("Hi")   # True
#all empty string are false

# %%
#common confiusion
name =input("enter  the name")#input is a string if you need int you need to do type converstion
print(name)
# Out:
# enter  the nameva
# va

# %%
#on float to int remove decimal value
int(5.9)
# Out:
# 5

# %%
#list
list("abc")
list([1,2,3])
# Out:
# [1, 2, 3]

# %%
#tuple
tuple([1,2,3])
tuple("bc")
# Out:
# ('b', 'c')

# %%
#set remove duplicates
x =[2,3,4,2,3]
set(x)
# Out:
# {2, 3, 4}

# %%
#operators
#1, Arithmetic +,-,/,//,%(reminder),**(power)
#Assigment : =,+=,-=,/=(just palce = after Arithamtic operator)
#comparision <,>,<=,>=,==.!=
#logical op:and ,or,not
#Sequential data types :it stores element in specfic order that can acess through indexing (String,list,tuple)
#unsequential:do not maintain a fixed order and the elements cannot access through indexing(set)

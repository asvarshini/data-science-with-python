# %% [markdown]
# Statictics in python used to perfom mean,median,mode,variance,sd.

# %%
#step 1 = import basic lib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#import file
df=pd.read_csv("/content/Country (1).csv")

# %%
#perfom normal EDA
df.columns
# Out:
# Index(['country', 'Region', 'Surface area (km2)',
#        'Population in thousands (2017)', 'Population density (per km2, 2017)',
#        'Sex ratio (m per 100 f, 2017)',
#        'GDP: Gross domestic product (million current US$)',
#        'GDP growth rate (annual %, const. 2005 prices)',
#        'GDP per capita (current US$)', 'Economy: Agriculture (% of GVA)',
#        'Economy: Industry (% of GVA)',
#        'Economy: Services and other activity (% of GVA)',
#        'Employment: Agriculture (% of employed)',
#        'Employment: Industry (% of employed)',
#        'Employment: Services (% of employed)',
#        'Unemployment (% of labour force)',
#        'Labour force participation (female/male pop. %)',
#        'Agricultural production index (2004-2006=100)',
#        'Food production index (2004-2006=100)',
#        'International trade: Exports (million US$)',
#        'International trade: Imports (million US$)',
# ...

# %%
#to know how many row and columns
df.shape
# Out:
# (229, 50)

# %%
df.info()  #no null values are present
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 50 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   country                                                     229 non-null    object
#  1   Region                                                      229 non-null    object
#  2   Surface area (km2)                                          229 non-null    object
#  3   Population in thousands (2017)                              229 non-null    int64
#  4   Population density (per km2, 2017)                          229 non-null    float64
#  5   Sex ratio (m per 100 f, 2017)                               229 non-null    float64
#  6   GDP: Gross domestic product (million current US$)           229 non-null    int64
# ...

# %%
#null value for allcoloums
df.isnull().sum()
# Out:
# country                                                       0
# Region                                                        0
# Surface area (km2)                                            0
# Population in thousands (2017)                                0
# Population density (per km2, 2017)                            0
# Sex ratio (m per 100 f, 2017)                                 0
# GDP: Gross domestic product (million current US$)             0
# GDP growth rate (annual %, const. 2005 prices)                0
# GDP per capita (current US$)                                  0
# Economy: Agriculture (% of GVA)                               0
# Economy: Industry (% of GVA)                                  0
# Economy: Services and other activity (% of GVA)               0
# Employment: Agriculture (% of employed)                       0
# Employment: Industry (% of employed)                          0
# Employment: Services (% of employed)                          0
# ...

# %%
#Null value in total data set
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
# staticstical data
df.describe()
# Out:
#        Population in thousands (2017)  Population density (per km2, 2017)  \
# count                    2.290000e+02                          229.000000
# mean                     3.275679e+04                          462.824891
# std                      1.332751e+05                         2305.384253
# min                      1.000000e+00                            0.100000
# 25%                      4.310000e+02                           35.900000
# 50%                      5.448000e+03                           88.100000
# 75%                      1.919300e+04                          222.800000
# max                      1.409517e+06                        25969.800000
#
#        Sex ratio (m per 100 f, 2017)  \
# count                     229.000000
# mean                      100.202183
# std                        28.327837
# min                       -99.000000
# 25%                        96.400000
# 50%                        99.000000
# ...

# %%
#How much of a country’s economy comes from the service sector
# i am having 233 country learning each country would be messier
df["Economy: Services and other activity (% of GVA)"].unique()#most valules are between 50 to 70
# Out:
# array([ 53.3,  51.7,  50.5, -99. ,  88.6,  42. ,  82. ,  79.8,  66.2,
#         52.8,  84.1,  71.1,  70.4,  43.4,  85.7,  59. ,  56.3,  86.2,
#         53.6,  77.1,  66.9,  51.9,  94. ,  38.8,  56.5,  64.2,  72. ,
#         87.8,  38.7,  67.2,  43.7,  49.8,  70.7,  42.3,  49.1,  69.6,
#         92.2,  40.4,  35.6,  63.3,  92.7,  93.4,  49.7,  59.2,  65.3,
#         25.3,  82.9,  73.4,  69.3,  74.5,  87.2,  59.7,  32.2,  35.9,
#         75.8,  75.3,  71.5,  65.4,  55.8,  52.5,  25.7,  59.3,  69.2,
#         43.5,  70.6,  78.8,  85.2,  41.7,  64. ,  68.9,  54.1,  80.2,
#         74.1,  77.8,  62. ,  40.5,  47.4,  50.6,  45.1,  61.9,  69.7,
#         53.2,  44.7,  52.3,  37.4,  57.3,  77.5,  74.2,  70.5,  72.4,
#         68.4,  62.5,  49. ,  62.2,  50.7,  58.7,  43.6,  73.5,  77.2,
#         61. ,  17.9,  32. ,  66.5,  87.7,  56.7,  51.8,  74.9,  83.6,
#         73.3,  74.4,  60.4,  65.8,  86.6,  51.1,  72.6,  85.9,  57.4,
# ...

# %%
sns.countplot(x='Economy: Services and other activity (% of GVA)',data=df,color="red")
plt.show()#knowing How much economy comes from the service sector in everyt country is different

# %%
#But in histograph i can say that many countryies  50 to 75 per economy from service sector
sns.histplot(x='Economy: Services and other activity (% of GVA)',data=df,kde=True,color="pink")
plt.show()#kde is used to check the skewness of
#only one -ve that may be outlayer

# %%
#find mean,median of coloumn
df["Population in thousands (2017)"].mean()
# Out:
# np.float64(32756.794759825327)

# %%
#find mean,median of coloumn
df["Population in thousands (2017)"].median()
# Out:
# 5448.0

# %%
#find mean,median of coloumn
df["Population in thousands (2017)"].mode()
# Out:
# 0        1
# 1       11
# 2       35
# 3       55
# 4       56
# 5      105
# 6      108
# 7      276
# 8      283
# 9     2890
# 10    2930
# Name: Population in thousands (2017), dtype: int64

# %%
#find mean,median of coloumn
df["Population in thousands (2017)"].unique()
# Out:
# array([  35530,    2930,   41318,      56,      77,   29784,      15,
#            102,   44271,     105,   24451,    8736,    9828,     395,
#           1493,  164670,     286,    9468,   11429,     375,   11176,
#             61,     808,   11052,      25,    3507,    2292,  209288,
#             31,     429,    7085,   19193,   10864,     546,   16005,
#          24054,   36624,      62,    4659,   14900,     165,   18055,
#           7365,     623, 1409517,   49066,     814,    5261,      17,
#           4906,    4189,   11485,    1180,   10618,   25491,   81340,
#           5734,     957,      74,   10767,   16625,   97553,    6378,
#           1268,    5069,    1310,  104957,       3,      49,     906,
#           5523,   64980,     283,    2025,    2101,    3912,   82114,
#          28834,      35,   11160,     108,     450,     164,   16914,
#           1861,   12717,     778,   10981,       1,    9265,    9722,
# ...
